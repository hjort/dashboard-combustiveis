# %%
import pandas as pd

# %%
from funcoes_apoio import preparar_dataframe

# %%
df = preparar_dataframe()
df
# Out:
#         regiao  uf               municipio               bairro   produto  \
# 3174408     NE  PE  VITORIA DE SANTO ANTAO             REDENCAO    ETANOL
# 3101236      S  SC          JARAGUA DO SUL           VILA LENZI  GASOLINA
# 1085417     NE  BA           CAMPO FORMOSO   BREJAO DA CAATINGA  GASOLINA
# 226295      SE  SP                  FRANCA  DISTRITO INDUSTRIAL  GASOLINA
# 2652822     NE  CE                 CAUCAIA               CAPUAN    ETANOL
# ...        ...  ..                     ...                  ...       ...
# 2394083     SE  MG                 CURVELO               CENTRO  GASOLINA
# 1748544     SE  SP                     JAU        JD STA HELENA  GASOLINA
# 1874454     SE  SP                   BAURU    JARDIM BELA VISTA  GASOLINA
# 2215731      S  PR                UMUARAMA  PARQUE INDUSTRIAL I    ETANOL
# 1643546     SE  SP                 ITATIBA           DO ENGENHO    ETANOL
#
#          venda  compra   ano  mes   bandeira  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 3174408 to 1643546
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   regiao     5000 non-null   category
#  1   uf         5000 non-null   category
#  2   municipio  5000 non-null   category
#  3   bairro     4983 non-null   category
#  4   produto    5000 non-null   category
#  5   venda      5000 non-null   float32
#  6   compra     5000 non-null   float32
#  7   ano        5000 non-null   uint16
#  8   mes        5000 non-null   uint8
#  9   bandeira   5000 non-null   object
#  10  revenda    5000 non-null   object
#  11  imputado   5000 non-null   category
#  12  ams        5000 non-null   int64
#  13  lucro      5000 non-null   float32
#  14  plucro     5000 non-null   float32
# dtypes: category(6), float32(4), int64(1), object(2), uint16(1), uint8(1)
# memory usage: 629.5+ KB

# %%
df.describe(include='all')
# Out:
#        regiao    uf  municipio  bairro   produto        venda       compra  \
# count    5000  5000       5000    4983      5000  5000.000000  5000.000000
# unique      5    27        506    2318         2          NaN          NaN
# top        SE    SP  SAO PAULO  CENTRO  GASOLINA          NaN          NaN
# freq     2546  1494        165     989      2673          NaN          NaN
# mean      NaN   NaN        NaN     NaN       NaN     3.467750     3.014622
# std       NaN   NaN        NaN     NaN       NaN     0.745009     0.688807
# min       NaN   NaN        NaN     NaN       NaN     1.499000     1.437000
# 25%       NaN   NaN        NaN     NaN       NaN     2.899000     2.491750
# 50%       NaN   NaN        NaN     NaN       NaN     3.479000     3.000000
# 75%       NaN   NaN        NaN     NaN       NaN     3.999000     3.510000
# max       NaN   NaN        NaN     NaN       NaN     5.479000     4.838000
#
# ...

# %%
for col in df.columns:
    print(df[[col]].value_counts(), "\n")
# Out:
# regiao
# SE        2546
# NE         981
# S          773
# CO         428
# N          272
# dtype: int64
#
# uf
# SP    1494
# MG     573
# RJ     395
# PR     301
# BA     290
# RS     280
# SC     192
# CE     184
# PE     178
# GO     176
# MT     115
# MS      93
# ES      84
# PA      75
# MA      73
# PB      67
# AM      63
# RN      60
# AL      53
# RO      50
# DF      44
# TO      40
# PI      38
# SE      38
# AC      23
# RR      12
# AP       9
# dtype: int64
#
# municipio
# SAO PAULO         165
# RIO DE JANEIRO     86
# FORTALEZA          82
# SALVADOR           67
# BELO HORIZONTE     54
#                  ...
# MAMANGUAPE          0
# JAGUARE             0
# JAGUARAO            0
# ITABAIANINHA        0
# NOVA LONDRINA       0
# Length: 596, dtype: int64
#
# bairro
# CENTRO                              989
# ZONA RURAL                           48
# SEDE                                 26
# BOA VISTA                            22
# ...

# %%
# %%script true
# df2 = df[['bandeira', 'regiao']].groupby('bandeira').count().\
#     reset_index().rename({'regiao': 'qtde'}, axis=1).\
#     sort_values('qtde', ascending=False)
# df2['perc'] = round(df2['qtde'] / len(df2), 2)
# df2

# %%
# %%script true
# def normalizar_bandeira(titulo):
#     if titulo in ['BRANCA', 'IPIRANGA', 'RAIZEN']:
#         return titulo
#     elif titulo == 'PETROBRAS DISTRIBUIDORA S.A.':
#         return 'PETROBRAS'
#     else:
#         return 'OUTRAS'
#
# df2['bandeira'].apply(normalizar_bandeira).head()

# %%
df['data'] = pd.to_datetime(df['ams'], format='%Y%m')
df
# Out:
#         regiao  uf               municipio               bairro   produto  \
# 3174408     NE  PE  VITORIA DE SANTO ANTAO             REDENCAO    ETANOL
# 3101236      S  SC          JARAGUA DO SUL           VILA LENZI  GASOLINA
# 1085417     NE  BA           CAMPO FORMOSO   BREJAO DA CAATINGA  GASOLINA
# 226295      SE  SP                  FRANCA  DISTRITO INDUSTRIAL  GASOLINA
# 2652822     NE  CE                 CAUCAIA               CAPUAN    ETANOL
# ...        ...  ..                     ...                  ...       ...
# 2394083     SE  MG                 CURVELO               CENTRO  GASOLINA
# 1748544     SE  SP                     JAU        JD STA HELENA  GASOLINA
# 1874454     SE  SP                   BAURU    JARDIM BELA VISTA  GASOLINA
# 2215731      S  PR                UMUARAMA  PARQUE INDUSTRIAL I    ETANOL
# 1643546     SE  SP                 ITATIBA           DO ENGENHO    ETANOL
#
#          venda  compra   ano  mes   bandeira  \
# ...

# %%
pd.to_datetime("202009", format='%Y%m')
# Out:
# Timestamp('2020-09-01 00:00:00')
