# %%
import pandas as pd

# %%
# !bzcat ca-2015-2022.csv.bz2 | head -5
# Out:
# regiao,uf,municipio,bairro,produto,venda,compra,unidade,ano,mes,dia,bandeira,revenda
# SE,SP,SOROCABA,JARDIM ZULMIRA,GASOLINA,3.11,,R$ / litro,2017,7,6,BRANCA,COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS DE PETROLEO LTDA
# SE,SP,SOROCABA,JARDIM ZULMIRA,ETANOL,2.02,,R$ / litro,2017,7,6,BRANCA,COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS DE PETROLEO LTDA
# SE,SP,SOROCABA,JARDIM ZULMIRA,DIESEL S10,2.86,,R$ / litro,2017,7,6,BRANCA,COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS DE PETROLEO LTDA
# NE,BA,ITABUNA,MANOEL LEAO,GASOLINA,3.599,,R$ / litro,2017,7,5,BRANCA,LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA
#
# bzcat: I/O or other error, bailing out.  Possible reason follows.
# bzcat: Broken pipe
# 	Input file = ca-2015-2022.csv.bz2, output file = (stdout)

# %%
# ler os dados do arquivo CSV
df = pd.read_csv("ca-2015-2022.csv.bz2",
                 dtype={'regiao': 'category', 'uf': 'category', 
                        'municipio': 'category', 'bairro': 'category',
                        'produto': 'category', 'venda': 'float32',
                        'compra': 'float32', 'unidade': 'category',
                        'ano': 'uint16', 'mes': 'uint8', 'dia': 'uint8'})

# %%
# manter apenas 2 tipos de produtos e remover unidade de medida
df = df[df['produto'].isin(['GASOLINA', 'ETANOL'])].drop('unidade', axis=1)
df
# Out:
#         regiao  uf             municipio           bairro   produto  venda  \
# 0           SE  SP              SOROCABA   JARDIM ZULMIRA  GASOLINA  3.110
# 1           SE  SP              SOROCABA   JARDIM ZULMIRA    ETANOL  2.020
# 3           NE  BA               ITABUNA      MANOEL LEAO  GASOLINA  3.599
# 6            S  PR           PATO BRANCO           CENTRO  GASOLINA  3.680
# 7            S  PR           PATO BRANCO           CENTRO    ETANOL  2.780
# ...        ...  ..                   ...              ...       ...    ...
# 6895492     CO  GO  APARECIDA DE GOIANIA  JARDIM HELVECIA    ETANOL  2.899
# 6895494     SE  MG          JUIZ DE FORA       INDUSTRIAL    ETANOL  2.960
# 6895497     NE  PI              PARNAIBA     SAO BENEDITO  GASOLINA  4.850
# 6895500     NE  BA             BARREIRAS           CENTRO  GASOLINA  4.599
# 6895501     NE  BA             BARREIRAS           CENTRO    ETANOL  3.049
#
#          compra   ano  mes  dia                      bandeira  \
# 0           NaN  2017    7    6                        BRANCA
# 1           NaN  2017    7    6                        BRANCA
# 3           NaN  2017    7    5                        BRANCA
# 6        3.0396  2017    7    4                        RODOIL
# 7           NaN  2017    7    4                        RODOIL
# ...         ...   ...  ...  ...                           ...
# 6895492  2.3550  2018    6   28                    RIO BRANCO
# 6895494  2.2850  2018    6   25                        BRANCA
# 6895497     NaN  2018    6   25  PETROBRAS DISTRIBUIDORA S.A.
# 6895500     NaN  2018    6   26  PETROBRAS DISTRIBUIDORA S.A.
# 6895501     NaN  2018    6   26  PETROBRAS DISTRIBUIDORA S.A.
#
#                                                    revenda
# 0        COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 1        COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 3                LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA
# 6                                     SANTOS & MERLO LTDA.
# 7                                     SANTOS & MERLO LTDA.
# ...                                                    ...
# 6895492                                 RE AUTO POSTO LTDA
# 6895494                                   POSTO FACIT LTDA
# 6895497                              V. MACHADO & CIA LTDA
# 6895500                              POSTO MACAUBENSE LTDA
# 6895501                              POSTO MACAUBENSE LTDA
#
# [3849547 rows x 12 columns]

# %%
# remover campo dia (irrelevante para a análise)
df.drop('dia', axis=1, inplace=True)
df
# Out:
#         regiao  uf             municipio           bairro   produto  venda  \
# 0           SE  SP              SOROCABA   JARDIM ZULMIRA  GASOLINA  3.110
# 1           SE  SP              SOROCABA   JARDIM ZULMIRA    ETANOL  2.020
# 3           NE  BA               ITABUNA      MANOEL LEAO  GASOLINA  3.599
# 6            S  PR           PATO BRANCO           CENTRO  GASOLINA  3.680
# 7            S  PR           PATO BRANCO           CENTRO    ETANOL  2.780
# ...        ...  ..                   ...              ...       ...    ...
# 6895492     CO  GO  APARECIDA DE GOIANIA  JARDIM HELVECIA    ETANOL  2.899
# 6895494     SE  MG          JUIZ DE FORA       INDUSTRIAL    ETANOL  2.960
# 6895497     NE  PI              PARNAIBA     SAO BENEDITO  GASOLINA  4.850
# 6895500     NE  BA             BARREIRAS           CENTRO  GASOLINA  4.599
# 6895501     NE  BA             BARREIRAS           CENTRO    ETANOL  3.049
#
#          compra   ano  mes                      bandeira  \
# 0           NaN  2017    7                        BRANCA
# 1           NaN  2017    7                        BRANCA
# 3           NaN  2017    7                        BRANCA
# 6        3.0396  2017    7                        RODOIL
# 7           NaN  2017    7                        RODOIL
# ...         ...   ...  ...                           ...
# 6895492  2.3550  2018    6                    RIO BRANCO
# 6895494  2.2850  2018    6                        BRANCA
# 6895497     NaN  2018    6  PETROBRAS DISTRIBUIDORA S.A.
# 6895500     NaN  2018    6  PETROBRAS DISTRIBUIDORA S.A.
# 6895501     NaN  2018    6  PETROBRAS DISTRIBUIDORA S.A.
#
#                                                    revenda
# 0        COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 1        COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 3                LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA
# 6                                     SANTOS & MERLO LTDA.
# 7                                     SANTOS & MERLO LTDA.
# ...                                                    ...
# 6895492                                 RE AUTO POSTO LTDA
# 6895494                                   POSTO FACIT LTDA
# 6895497                              V. MACHADO & CIA LTDA
# 6895500                              POSTO MACAUBENSE LTDA
# 6895501                              POSTO MACAUBENSE LTDA
#
# [3849547 rows x 11 columns]

# %%
# manter apenas medições até o ano de 2020
df = df[df['ano'] <= 2020]
df
# Out:
#         regiao  uf             municipio           bairro   produto  venda  \
# 0           SE  SP              SOROCABA   JARDIM ZULMIRA  GASOLINA  3.110
# 1           SE  SP              SOROCABA   JARDIM ZULMIRA    ETANOL  2.020
# 3           NE  BA               ITABUNA      MANOEL LEAO  GASOLINA  3.599
# 6            S  PR           PATO BRANCO           CENTRO  GASOLINA  3.680
# 7            S  PR           PATO BRANCO           CENTRO    ETANOL  2.780
# ...        ...  ..                   ...              ...       ...    ...
# 6895492     CO  GO  APARECIDA DE GOIANIA  JARDIM HELVECIA    ETANOL  2.899
# 6895494     SE  MG          JUIZ DE FORA       INDUSTRIAL    ETANOL  2.960
# 6895497     NE  PI              PARNAIBA     SAO BENEDITO  GASOLINA  4.850
# 6895500     NE  BA             BARREIRAS           CENTRO  GASOLINA  4.599
# 6895501     NE  BA             BARREIRAS           CENTRO    ETANOL  3.049
#
#          compra   ano  mes                      bandeira  \
# 0           NaN  2017    7                        BRANCA
# 1           NaN  2017    7                        BRANCA
# 3           NaN  2017    7                        BRANCA
# 6        3.0396  2017    7                        RODOIL
# 7           NaN  2017    7                        RODOIL
# ...         ...   ...  ...                           ...
# 6895492  2.3550  2018    6                    RIO BRANCO
# 6895494  2.2850  2018    6                        BRANCA
# 6895497     NaN  2018    6  PETROBRAS DISTRIBUIDORA S.A.
# 6895500     NaN  2018    6  PETROBRAS DISTRIBUIDORA S.A.
# 6895501     NaN  2018    6  PETROBRAS DISTRIBUIDORA S.A.
#
#                                                    revenda
# 0        COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 1        COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 3                LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA
# 6                                     SANTOS & MERLO LTDA.
# 7                                     SANTOS & MERLO LTDA.
# ...                                                    ...
# 6895492                                 RE AUTO POSTO LTDA
# 6895494                                   POSTO FACIT LTDA
# 6895497                              V. MACHADO & CIA LTDA
# 6895500                              POSTO MACAUBENSE LTDA
# 6895501                              POSTO MACAUBENSE LTDA
#
# [3212940 rows x 11 columns]

# %%
# remover campos valor de compra (73% nulos) e dia (irrelevante para a análise)
#df.drop(['compra', 'dia'], axis=1, inplace=True)
#df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3212940 entries, 0 to 6895501
# Data columns (total 11 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   regiao     category
#  1   uf         category
#  2   municipio  category
#  3   bairro     category
#  4   produto    category
#  5   venda      float32
#  6   compra     float32
#  7   ano        uint16
#  8   mes        uint8
#  9   bandeira   object
#  10  revenda    object
# dtypes: category(5), float32(2), object(2), uint16(1), uint8(1)
# memory usage: 129.0+ MB

# %%
df.describe(include='all')
# Out:
#          regiao       uf  municipio   bairro   produto         venda  \
# count   3212940  3212940    3212940  3201604   3212940  3.212940e+06
# unique        5       27        596     7793         2           NaN
# top          SE       SP  SAO PAULO   CENTRO  GASOLINA           NaN
# freq    1616876   961826     106867   621037   1693687           NaN
# mean        NaN      NaN        NaN      NaN       NaN  3.459790e+00
# std         NaN      NaN        NaN      NaN       NaN  7.462451e-01
# min         NaN      NaN        NaN      NaN       NaN  1.390000e+00
# 25%         NaN      NaN        NaN      NaN       NaN  2.899000e+00
# 50%         NaN      NaN        NaN      NaN       NaN  3.490000e+00
# 75%         NaN      NaN        NaN      NaN       NaN  3.999000e+00
# max         NaN      NaN        NaN      NaN       NaN  6.290000e+00
#
#               compra           ano           mes bandeira  \
# count   1.279575e+06  3.212940e+06  3.212940e+06  3212940
# unique           NaN           NaN           NaN      106
# top              NaN           NaN           NaN   BRANCA
# freq             NaN           NaN           NaN  1039714
# mean    2.996882e+00  2.017322e+03  6.026935e+00      NaN
# std     6.995669e-01  1.708042e+00  3.377633e+00      NaN
# min     1.171400e+00  2.015000e+03  1.000000e+00      NaN
# 25%     2.468000e+00  2.016000e+03  3.000000e+00      NaN
# 50%     2.987100e+00  2.017000e+03  6.000000e+00      NaN
# 75%     3.500000e+00  2.019000e+03  9.000000e+00      NaN
# max     5.091000e+00  2.020000e+03  1.200000e+01      NaN
#
#                                     revenda
# count                               3212940
# unique                                19614
# top     CARREFOUR COMERCIO E INDUSTRIA LTDA
# freq                                   8305
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN

# %%
# gerar arquivo CSV filtrado
arquivo_saida = "ge-2015-2020.csv.bz2"
df.to_csv(arquivo_saida, index=False, encoding='utf-8')
